# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import pandas as pd
import time
from selenium.common.exceptions import NoSuchElementException
from tqdm import tqdm

# %%
df=pd.read_csv(r"first_tble.csv")

# %%
#`name` - Name of the medicine

#`brand_name`  - Brand name

#key_benefits` - Key Benefits area (Hair, eye, joint, skin)

#`key_ingredients` - Ingredient of medicine

#`rating` - user rating of the medicine

#`number_of_rating`  - Number of people rated that product

# %%
df.head()
# Out:
#                                                 Name  \
# 0  Dr Willmar Schwabe India Terminalia Chebula Di...
# 1                                SBL Silicea 0/24 LM
# 2  Dr. Majumder Homeo World Blumea Odorata Diluti...
# 3               Bjain Kalium Iodatum Dilution 10M CH
# 4          LDD Bioscience Guaiacum Mother Tincture Q
#
#                                Size  Price  \
# 0          bottle of 30 ml Dilution    NaN
# 1          bottle of 20 gm Globules    NaN
# 2                   box of 1 Bottle  230.0
# 3          bottle of 30 ml Dilution  270.0
# 4  bottle of 100 ml Mother Tincture  945.0
#
#                                                 Link              MRP
# 0  https://www.1mg.com/otc/dr-willmar-schwabe-ind...              NaN
# 1  https://www.1mg.com/otc/sbl-silicea-0-24-lm-ot...              NaN
# 2  https://www.1mg.com/otc/dr.-majumder-homeo-wor...   MRP₹27015% OFF
# 3  https://www.1mg.com/otc/bjain-kalium-iodatum-d...   MRP₹30010% OFF
# ...

# %%
df['Link']
# Out:
# 0       https://www.1mg.com/otc/dr-willmar-schwabe-ind...
# 1       https://www.1mg.com/otc/sbl-silicea-0-24-lm-ot...
# 2       https://www.1mg.com/otc/dr.-majumder-homeo-wor...
# 3       https://www.1mg.com/otc/bjain-kalium-iodatum-d...
# 4       https://www.1mg.com/otc/ldd-bioscience-guaiacu...
#                               ...
# 1438    https://www.1mg.com/otc/dr-willmar-schwabe-ind...
# 1439    https://www.1mg.com/otc/haslab-hc-37-caladium-...
# 1440    https://www.1mg.com/otc/sbl-viola-tricolor-dil...
# 1441    https://www.1mg.com/otc/bakson-s-homeopathy-ph...
# 1442    https://www.1mg.com/otc/pioneer-pharma-kali-br...
# Name: Link, Length: 1443, dtype: object

# %%
name_arr = []
rating_arr = []
brand_arr = []
no_rating_arr = [] 
key_benefit_arr = []

for i in tqdm(df['Link']):

    driver = webdriver.Chrome()
    driver.get(i)
    time.sleep(2)

    try:
        name = driver.find_element(By.XPATH, '//*[@id="container"]/div/div/div[2]/div[3]/div[1]/div[1]/h1').text
    except NoSuchElementException:
        name = None

    try:
        brand = driver.find_element(By.XPATH, '//*[@id="container"]/div/div/div[2]/div[3]/div[1]/div[2]/a').text
    except NoSuchElementException:
        brand = None

    try:
        rating = driver.find_element(By.XPATH, '//*[@id="container"]/div/div/div[2]/div[3]/div[1]/div[3]/div').text
    except NoSuchElementException:
        rating = None

    try:
        no_rating = driver.find_element(By.XPATH, '//*[@id="container"]/div/div/div[2]/div[3]/div[1]/div[3]/span').text
    except NoSuchElementException:
        no_rating = None

    try:
        key_benefit_elements = driver.find_elements(By.XPATH, '//*[@id="container"]/div/div/div[3]/div[1]/div[2]/div[2]/ul/li')
        key_benefit = [ele.text for ele in key_benefit_elements]
    except NoSuchElementException:
        key_benefit = None

    name_arr.append(name)
    brand_arr.append(brand)
    rating_arr.append(rating)
    no_rating_arr.append(no_rating)
    key_benefit_arr.append(key_benefit)

    driver.close()
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████| 1443/1443 [6:25:08<00:00, 16.01s/it]

# %%
data = {
    'Name': name_arr,
    'brand': brand_arr,
    'rating': rating_arr,
    'no_rating': no_rating_arr,
    'key_benefit': key_benefit_arr
}
df2 = pd.DataFrame(data)

# %%
df2.head()
# Out:
#                                                 Name  \
# 0  Dr Willmar Schwabe India Terminalia Chebula Di...
# 1                                SBL Silicea 0/24 LM
# 2  Dr. Majumder Homeo World Blumea Odorata Diluti...
# 3               Bjain Kalium Iodatum Dilution 10M CH
# 4          LDD Bioscience Guaiacum Mother Tincture Q
#
#                               brand rating   no_rating  \
# 0  Dr Willmar Schwabe India Pvt Ltd   None        None
# 1                       SBL Pvt Ltd    4.6  12 Ratings
# 2          Dr. Majumder Homeo World   None        None
# 3   Bjain Pharmaceuticals Pvt. Ltd.   None        None
# 4            LDD Bioscience Pvt Ltd   None        None
#
#                           key_benefit
# 0                [, , , , , , , , , ]
# 1  [, , , , , , , , , , , , , , , , ]
# 2                    [, , , , , , , ]
# 3                      [, , , , , , ]
# 4                                  []

# %%
df2.to_csv("Second_tble.csv",index=False)

# %%
#//*[@id="container"]/div/div/div[2]/div[3]/div[1]/div[2]/a
#//*[@id="container"]/div/div/div[2]/div[3]/div[1]/div[2]/a
#//*[@id="container"]/div/div/div[2]/div[3]/div[1]/div[2]/a

# %%
#rating
#//*[@id="container"]/div/div/div[2]/div[3]/div[1]/div[3]/div
#//*[@id="container"]/div/div/div[2]/div[3]/div[1]/div[3]/div

# %%
#for i in df['Link']:
   # print(i)
    #driver = webdriver.Chrome()
   # driver.get(i)
   # time.sleep(5)
    #x_path_name = '//*[@id="container"]/div/div/div[2]/div[3]/div[1]/div[1]/h1'
   # element = driver.find_element(by=By.XPATH, value=x_path_name)
    #name = element.text
    #x_path_brand = '//*[@id="container"]/div/div/div[2]/div[3]/div[1]/div[2]/a'
    #element = driver.find_
   # element(by=By.XPATH, value=x_path_brand)
   # brand = element.text
    #print(brand)
    #x_path_rating = '//*[@id="container"]/div/div/div[2]/div[3]/div[1]/div[3]/div'
   # element = driver.find_element(by=By.XPATH, value=x_path_rating)
    #rating = element.text
   # print(rating)
    #driver.close()
   # break

# %%
#//*[@id="container"]/div/div/div[2]/div[3]/div[1]/div[3]/span
#//*[@id="container"]/div/div/div[2]/div[3]/div[1]/div[3]/span
#
#//*[@id="container"]/div/div/div[3]/div[1]/div[2]/div[2]/ul[{i}]/li
#//*[@id="container"]/div/div/div[3]/div[1]/div[2]/div[2]/ul[2]/li
#//*[@id="container"]/div/div/div[3]/div[1]/div[2]/div[2]/ul[3]/li

# %%
#//*[@id="container"]/div/div/div[3]/div[1]/div[2]/div[2]/ul[1]/li
#//*[@id="container"]/div/div/div[3]/div[1]/div[2]/div[2]/ul[11]/li
#//*[@id="container"]/div/div/div[3]/div[1]/div[2]/div[2]/ul[9]/li

# %%
#for i in df['Link']:
   # print(i)
    #driver = webdriver.Chrome()
    #driver.get(i)
   # time.sleep(5)
   # name_arr = []
    #brand_arr = []
    #rating_arr = []
   # no_rating_arr =[]
   # key_benifit_arr = []
       

    

    
    #x_path_name=f'//*[@id="container"]/div/div/div[2]/div[3]/div[1]/div[1]/h1'
   # element = driver.find_element(by=By.XPATH, value=x_path_name)
   # name = element.text
    
   # x_path_brand=f'//*[@id="container"]/div/div/div[2]/div[3]/div[1]/div[2]/a'
  #  element = driver.find_element(by=By.XPATH, value= x_path_brand)
   # brand = element.text
    #print(brand)
   # except:
   # try:
       # x_path_rating=f'//*[@id="container"]/div/div/div[2]/div[3]/div[1]/div[3]/div'
        #element = driver.find_element(by=By.XPATH, value=x_path_rating)
        #rating = element.text
       # print(rating)
   # except:
        #rating = none
   # try:
       # x_path_no_rating=f'//*[@id="container"]/div/div/div[2]/div[3]/div[1]/div[3]/span'
       # element = driver.find_element(by=By.XPATH, value=x_path_no_rating)
       # no_rating= element.text
       # print(no_rating)
    #except Exception as e:
       # no_rating= none
    #x_path_key_benifit=f'//*[@id="container"]/div/div/div[3]/div[1]/div[2]/div[2]/ul'
   # elements = driver.find_elements(by=By.XPATH, value=x_path_key_benifit)
   # print(len(elements))
   # temp_arr = []
    #for ele in elements:
        #temp_arr.append(ele.get_attribute('innerHTML'))
    #print(temp_arr)
